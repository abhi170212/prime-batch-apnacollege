# %%
import pandas as pd

# %%
info = {
    "name":["abhishek","ahmed","layla","abu saed","waheed"],
    "cgpa":[7.6,8.1,7.1,7.0,9],
    "country":["India","Turkiye","Tu
}
# Out:
#   Cell In[2], line 1
#     pd.
#        ^
# SyntaxError: invalid syntax
